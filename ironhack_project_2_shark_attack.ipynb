# %% [markdown]
# ## SHARK ATTACKS - WHERE DO THEY HAPPEN MORE, WHEN, TO WHICH SEX AND RELATED TO WHICH ACTIVITY?

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
srk_atk = pd.read_csv('attacks.csv', sep=",", index_col = 0, encoding='latin-1')
srk_atk
# Out:
#                     Date    Year        Type    Country             Area  \
# Case Number
# 2018.06.25   25-Jun-2018  2018.0     Boating        USA       California
# 2018.06.18   18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2018.06.09   09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 2018.06.08   08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04   04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...                  ...     ...         ...        ...              ...
# NaN                  NaN     NaN         NaN        NaN              NaN
# NaN                  NaN     NaN         NaN        NaN              NaN
# NaN                  NaN     NaN         NaN        NaN              NaN
# NaN                  NaN     NaN         NaN        NaN              NaN
# xx                   NaN     NaN         NaN        NaN              NaN
#
#                                    Location     Activity             Name  \
# ...

# %%
srk_atk.head()
# Out:
#                     Date    Year        Type    Country             Area  \
# Case Number
# 2018.06.25   25-Jun-2018  2018.0     Boating        USA       California
# 2018.06.18   18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2018.06.09   09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 2018.06.08   08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2018.06.04   04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                                    Location     Activity             Name  \
# Case Number
# 2018.06.25      Oceanside, San Diego County     Paddling      Julie Wolfe
# 2018.06.18   St. Simon Island, Glynn County     Standing  Adyson McNeely
# 2018.06.09                     Habush, Oahu      Surfing      John Denges
# 2018.06.08               Arrawarra Headland      Surfing             male
# 2018.06.04                         La Ticla  Free diving   Gustavo Ramos
#
# ...

# %%
srk_atk.shape
# Out:
# (25723, 23)

# %%
srk_atk.size
# Out:
# 591629

# %%
srk_atk.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
srk_atk['Country']
# Out:
# Index([  '2018.06.25',   '2018.06.18',   '2018.06.09',   '2018.06.08',
#          '2018.06.04', '2018.06.03.b', '2018.06.03.a',   '2018.05.27',
#        '2018.05.26.b', '2018.05.26.a',
#        ...
#                   nan,            nan,            nan,            nan,
#                   nan,            nan,            nan,            nan,
#                   nan,           'xx'],
#       dtype='object', name='Case Number', length=25723)

# %%
len(srk_atk.columns)
# Out:
# 23

# %%
srk_atk.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
srk_atk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25723 entries, 2018.06.25 to xx
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    6302 non-null   object
#  1   Year                    6300 non-null   float64
#  2   Type                    6298 non-null   object
#  3   Country                 6252 non-null   object
#  4   Area                    5847 non-null   object
#  5   Location                5762 non-null   object
#  6   Activity                5758 non-null   object
#  7   Name                    6092 non-null   object
#  8   Sex                     5737 non-null   object
#  9   Age                     3471 non-null   object
#  10  Injury                  6274 non-null   object
#  11  Fatal (Y/N)             5763 non-null   object
#  12  Time                    2948 non-null   object
#  13  Species                 3464 non-null   object
# ...

# %%
srk_atk.dtypes
# Out:
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
srk_atk.isna()
# Out:
#               Date   Year   Type  Country   Area  Location  Activity   Name  \
# Case Number
# 2018.06.25   False  False  False    False  False     False     False  False
# 2018.06.18   False  False  False    False  False     False     False  False
# 2018.06.09   False  False  False    False  False     False     False  False
# 2018.06.08   False  False  False    False  False     False     False  False
# 2018.06.04   False  False  False    False  False     False     False  False
# ...            ...    ...    ...      ...    ...       ...       ...    ...
# NaN           True   True   True     True   True      True      True   True
# NaN           True   True   True     True   True      True      True   True
# NaN           True   True   True     True   True      True      True   True
# NaN           True   True   True     True   True      True      True   True
# xx            True   True   True     True   True      True      True   True
#
# ...

# %%
srk_cl = srk_atk.drop(columns=['Unnamed: 22', 'Unnamed: 23', 'href formula', 'href', 'Injury', 'Fatal (Y/N)', 'Location', 'Species ', 'Area', 'pdf', 'Time', 'Investigator or Source', 'Case Number.1', 'Case Number.2', 'original order'])
srk_cl
# Out:
#                     Date    Year        Type    Country     Activity  \
# Case Number
# 2018.06.25   25-Jun-2018  2018.0     Boating        USA     Paddling
# 2018.06.18   18-Jun-2018  2018.0  Unprovoked        USA     Standing
# 2018.06.09   09-Jun-2018  2018.0     Invalid        USA      Surfing
# 2018.06.08   08-Jun-2018  2018.0  Unprovoked  AUSTRALIA      Surfing
# 2018.06.04   04-Jun-2018  2018.0    Provoked     MEXICO  Free diving
# ...                  ...     ...         ...        ...          ...
# NaN                  NaN     NaN         NaN        NaN          NaN
# NaN                  NaN     NaN         NaN        NaN          NaN
# NaN                  NaN     NaN         NaN        NaN          NaN
# NaN                  NaN     NaN         NaN        NaN          NaN
# xx                   NaN     NaN         NaN        NaN          NaN
#
#                         Name Sex   Age
# Case Number
# 2018.06.25       Julie Wolfe    F   57
# ...

# %%
num_attacks_country = srk_cl["Country"].value_counts().nlargest(9)
num_attacks_country.sort_values(ascending=True, inplace=True)
num_attacks_country.plot.barh(color="royalblue")

plt.title("Unprovoked Shark Attacks by Country (1967-2017)")
plt.xlabel("Attacks")

plt.grid(axis="x")
plt.tight_layout()
plt.savefig("AttacksByCountry.png")

# %%
num_attacks_country = srk_cl["Year"].value_counts().nlargest(5)
num_attacks_country.sort_values(ascending=True, inplace=True)
num_attacks_country.plot.barh(color="red")

plt.title("Unprovoked Shark Attacks by Year")
plt.xlabel("Attacks")

plt.grid(axis="x")
plt.tight_layout()
plt.savefig("AttacksByYear.png")

# %%
num_attacks_country = srk_cl["Sex "].value_counts().nlargest(2)
num_attacks_country.sort_values(ascending=True, inplace=True)
num_attacks_country.plot.barh(color="teal")

plt.title("Unprovoked Shark Attacks by Sex")
plt.xlabel("Attacks")

plt.grid(axis="x")
plt.tight_layout()
plt.savefig("AttacksByYear.png")

# %%
num_attacks_country = srk_cl["Activity"].value_counts().nlargest(9)
num_attacks_country.sort_values(ascending=True, inplace=True)
num_attacks_country.plot.barh(color="darkgreen")

plt.title("Unprovoked Shark Attacks by Acitivity")
plt.xlabel("Attacks")

plt.grid(axis="x")
plt.tight_layout()
plt.savefig("AttacksByYear.png")
